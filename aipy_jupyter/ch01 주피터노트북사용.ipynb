# %% [markdown]
# ### 3rd level

# %%
a = 10
print('Hello', a)
# Out:
# Hello 10

# %% [markdown]
# **BOLD** chracter
# - a
#  - aa
#   - aaa
#    - aaaa
# - b
# > crap
#
# ```python
# a = 10
# print(a)
# ```
# - [URL link](http://www.google.com/)
